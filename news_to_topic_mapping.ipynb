# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain.docstore.document import Document
from dotenv import load_dotenv
import os
import numpy as np

# %%
static_topics = ["Supplier Environmental Assessment", "Materials", "Energy", "Waste", "Water & Effluents", "Emissions", "Environmental Compliance", "Biodiversity"]

def generate_static_topic_desc(static_topics: list[str], llm):
    topic_desc = {}
    for topic in static_topics:
        topic_desc[topic] = llm.invoke(f"Generate a detailed paragraph explaining the topic {topic}").content

    return topic_desc

def generate_topic_embeddings(topic_desc: dict[str, str], embeddings_model):
    embeddings = embeddings_model.embed_documents(list(topic_desc.values()))
    
    topic_desc_embeddings = {}
    for i, topic in enumerate(topic_desc.keys()):
        topic_desc_embeddings[topic] = embeddings[i]

    return topic_desc_embeddings

def get_topic_embedding_db(topic_desc: dict[str, str], embeddings_model):
    documents = [Document(page_content=desc, metadata={"topic": topic}) for topic, desc in topic_desc.items()]
    vector_db = Chroma.from_documents(documents=documents, embedding=embeddings_model)

    return vector_db

def map_lda2topic(lda_topics, static_topic_db):
    mapped_topics = []
    retriever = static_topic_db.as_retriever(search_type='similarity')
    for topic in lda_topics:
        retrieved = retriever.invoke(topic, search_kwargs={"k": 1})

        mapped_topics.append(retrieved[0].metadata["topic"])

    return mapped_topics

# %%
dot_env_path = os.path.join(os.getcwd(), '.env')

if os.path.exists(dot_env_path):
    load_dotenv(dot_env_path)

llm = ChatOpenAI()
embeddings_model = OpenAIEmbeddings()

# %%
topic_desc = generate_static_topic_desc(static_topics, llm)

# %%
# topic_desc_emb = generate_topic_embeddings(topic_desc, embeddings_model)

# %%
vector_topic_db = get_topic_embedding_db(topic_desc, embeddings_model)

# %%
with open("../topics_IN.txt") as f:
    file = f.readlines()
    file = [line.split(":")[1].lstrip() for line in file]

# %%
ld2map = map_lda2topic(file, vector_topic_db)

# %%
import pandas as pd

df = pd.DataFrame()

for i, (topic, category) in enumerate(zip(file, ld2map)):
    df_ = pd.DataFrame({"index": [f"Topic_{i+1}"], "topic": [topic], "category": [category]})
    df = pd.concat([df, df_], ignore_index=True)

# %%
df
# Out:
#        index                                              topic  \
# 0    Topic_1  climate change himalayan national capacity tec...
# 1    Topic_2  mission national eco system himalayan sustaini...
# 2    Topic_3  climate change national action plan developmen...
# 3    Topic_4  forest ha climate ecosystem adaptation change ...
# 4    Topic_5  soil health card nutrient provide farmer impro...
# 5    Topic_6  water resource per management area ensure prom...
# 6    Topic_7  fodder carbon around another annual well timbe...
# 7    Topic_8  national mission sustainable green water india...
# 8    Topic_9  energy efficiency mission solar gw power nmeee...
# 9   Topic_10  sustainable energy efficiency aim management s...
# 10  Topic_11  area climate technology sub energy water agric...
# 11  Topic_12  climate change natural impact agriculture fore...
# 12  Topic_13  change climate natural adaptation efficiency f...
# 13  Topic_14  service change climate timber forest knowledge...
# 14  Topic_15  vulnerability demonstrated change climate even...
# 15  Topic_16  fodder carbon around another annual well timbe...
# 16  Topic_17  fodder carbon around another annual well timbe...
# 17  Topic_18  mission change climate development national su...
# 18  Topic_19  solar soil fertilizer objective nutrient impro...
# 19  Topic_20  water mission efficiency national use technolo...
#
#                     category
# 0               Biodiversity
# 1               Biodiversity
# 2                  Emissions
# 3               Biodiversity
# 4               Biodiversity
# 5          Water & Effluents
# 6                  Emissions
# 7          Water & Effluents
# 8                     Energy
# 9   Environmental Compliance
# 10                 Emissions
# 11                 Emissions
# 12                 Emissions
# 13              Biodiversity
# 14                 Emissions
# 15                 Emissions
# 16                 Emissions
# 17                 Emissions
# 18                 Emissions
# 19                    Energy

# %%
df.to_csv('../topics_IN.csv', index=False)

# %% [markdown]
# ## Experiments

# %%
import pandas as pd
